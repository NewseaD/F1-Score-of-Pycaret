# %%
import os,gc
gc.collect()
# Out:
# 38

# %%
# 首先，计算出bureau表格的贷款次数
import numpy as np
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from pycaret.classification import *

# %%
columns=['Frequency', 'InstlmentMode', 'LoanStatus', 'PaymentMode',
       'BranchID', 'Tenure', 'AssetCost', 'AmountFinance', 'DisbursalAmount',
         'EMI','LTV', 'SEX', 'MonthlyIncome', 'State',
         'Top-up Month', 'SELF-INDICATOR', 'AMT OVERDUE - HIST','YearsOfService', 'D_Year', 'D_Month', 'D_Day', 'D_Quarter',
       'DayofWeek','ACCT-TYPE_Business Loan Priority Sector  Agriculture',
       'ACCT-TYPE_Other', 'ACCT-TYPE_Tractor Loan']
diabetes= pd.read_csv('D:/GraduateDesign/LTFS/Final/allDataTrain_concat_ACCT_noNAN.csv',usecols=columns)

# %%
clf = setup(data = diabetes, target = 'Top-up Month',session_id=0)
# Out:
# <style type="text/css">
# #T_38a16_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_38a16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38a16_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_38a16_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38a16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38a16_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_38a16_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38a16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38a16_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_38a16_row1_col1" class="data row1 col1" >Top-up Month</td>
#     </tr>
#     <tr>
#       <th id="T_38a16_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lightgbm= create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_14d7c_row10_col0, #T_14d7c_row10_col1, #T_14d7c_row10_col2, #T_14d7c_row10_col3, #T_14d7c_row10_col4, #T_14d7c_row10_col5, #T_14d7c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_14d7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14d7c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_14d7c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_14d7c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_14d7c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_14d7c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_14d7c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_14d7c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14d7c_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# plotting a model
plot_model(lightgbm,plot = 'confusion_matrix')
